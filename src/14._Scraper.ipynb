# %% [markdown]
# # Проект - скрапер HTML-страниц
#
# Представим, что нам нужны некоторые данные, которые мы можем получить только с веб-страницы. То есть нет ни таблиц, ни файлов, ни архивов, ни баз данных, где они лежат, а есть только несколько веб-страниц, прямо на которых описаны эти данные. В этом случае нам нужно "заскрапить" (scrape) эти данные. Для этого существует библиотека Beautiful Soup.
#
# ## Постановка задачи
#
# Мы напишем не только сам алгоритм скраппинга страницы, но и некоторые дополнительные классы, которые будет удобно использовать для сбора данных. Также продумаем единую точку входа в наш проект, чтобы им можно было удобно пользоваться.
#
# Архитектура модуля будет следующей. Структура файлов:
#
#     scraper
#     |- download.py
#     |- parse.py
#     |- data.py
#     |- __init__.py
#
# Таким образом, наш модуль будет разделен на 3 части: файл, в котором описана логика сохранения веб-страницы на локальный копьютер; файл, в котором описан класс-парсер скаченной страницы; а также файл, где будет описана работа с получившимися файлами. Также опишем файл `__init__.py`, в котором будут общие функции, которые помогут использовать весь наш модуль одной строчкой.
#
# ### Почему такое странное название файла?
#
# В уроке про модули мы с вами узнали, что любой файл является модулем, который можно импортировать. Например, при такой структуре файлов:
#
#     |- a.py
#     |- b.py
#
# в файле b.py допустим следующим импорт: `from a import *`, поскольку эти файлы лежат в одной папке. Если же файл a.py лежит в подпапке, т.е. вот так:
#
#     |- a_dir
#     |  |- a.py
#     |
#     |- b.py
#
# то логично предположить, что код из него в b.py можно импортировать командой `from a_dir.a import *`, но не тут-то было. Дело в том, что папка в питоне является модулем, если в ней есть файл с названием `__init__.py`, иначе мы не можем взаимодействовать с кодом в этой папке из других модулей. Больше того, код, описанный в этом файле, будет доступен файлов, соседствующих с папкой, через команду `from a_dir import *`, и именно такой формат импорта мы будем считать самым удобным для пользователей нашего модуля.
#
# ## Что будем скрапить?
#
# Это вам решать! Найдите любую страницу в интернете, где описаны какие-нибудь данные, и используйте их. В небольших примерах кода будем использовать данные о погоде в Мурманске с сайта [Метеоновости](http://www.hmn.ru/index.php?index=8&value=22113&tz=3&start=2022-11-20&fin=2022-11-28&x=10&y=5).
#
# ---
#
# Теперь опишем подробнее, что должно быть реализовано внутри каждого из этих файлов.

# %% [markdown]
# ## 1. `download.py`
#
# Начнем с файла, в котором описано скачивание веб-страницы на локальный компьютер. Назовем класс-обертку для этого `Downloader`. Суть этого класса в том, что его объект должен содержать четыре вещи:
#
# - адрес страницы, которую мы скрапим;
# - параметры, которые мы подаем по этому адресу;
# - метод, которым мы обращаемся по адресу, чтобы получить страницу;
# - путь к файлу на локальном компьютере, в который будет сохранен исходный код веб-страницы.
#
# Таким образом, объекты этого класса должны иметь возможность следующего использования:

# %%
import requests
# URL = "http://www.hmn.ru/index.php"      # тут используйте адрес вашего сайта
# PARAMS = {                               # эти параметры также индивидуальны для страницы, которую вы скрапите
#     "index": 8,
#     "value": 22113,
#     "tz": 3,
#     "start": "2022-11-20",
#     "fin": "2022-11-28",
#     "x": 10,
#     "y": 5,
# }
FILE_PATH = "weather.html"               # используйте ваше название. Будет более понятно, если будете исполь-                  
class Downloader:                        # зовать расширение html, т.к. в этом файле будет код html-страницы
    def __init__(self, url, params, method="GET", file_path=FILE_PATH):
        self.url = url
        self.params = params
        self.method = method
        self._file_path = file_path
        self.save(file_path)
    def get_html(self):
        reg = requests.get(self.url, self.params, stream=True)
        text = reg.text
        return text
    def save(self, File_path):
        with open(File_path, "w", encoding='koi8-r') as file:
            file.write(self.get_html())
    def get_file_path(self):
        self.save(self._file_path)
        return self._file_path
    file_path = property(get_file_path)
# downloader = Downloader(url=URL, params=PARAMS, method="GET")
# print(downloader.get_html())       # этот метод возвращает строку с контентом, которую получил по запросу на URL
# downloader.save(FILE_PATH)  # метод сохраняет полученную строку в файл, путь к которому подается в аргументе
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html><head><title>Мурманск : архив погоды</title>
#    <meta name="author" content="Maxim Savtchenko">
#    <meta name="generator" content="EditPlus">
#    <meta name="Copyrigth" content="(C) WWW.METEONOVOSTI.RU, 2008">
#    <meta name="keywords" content="Архив погоды,Архив погоды по городам мира">
#    <meta name="description" content="Архив погоды по городам мира">
#
#    <meta name="yandex-verification" content="4d3d1372cce94f6f" />
#    <meta property="og:image" content="http://hmn.ru/img/meteonovosti.png">
#    <link rel="stylesheet" href="css/styles1.css" type="text/css">
#    <link rel="stylesheet" href="css/clicktravel.css" type="text/css"><link rel="stylesheet" href="css/weather.css" type="text/css"> <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/207129/360.js"></script>
#  <script async type='text/javascript' src='//s.luxupcdnc.com/t/common_402.js'></script>
# </head>
# <body bgcolor="white" topmargin="0" marginheight="0">
# <script class='__lxGc__' type='text/javascript'>
# ((__lxGc__=window.__lxGc__||{'s':{},'b':0})['s']['_207129']=__lxGc__['s']['_207129']||{'b':{}})['b']['_670727']={'i':__lxGc__.b++};
# </script>
# <center><div id="counters" style="position:absolute; display:none; width:1px; height:1px; z-index:-1"><IMG SRC="http://ww.hmn.ru/counterdb.php?data=MTc4LjIwNy4xNTQuMjUzPyEjMTc4LjIwNy4xNTQuMjUzPyEjcHl0aG9uLXJlcXVlc3RzLzIuMjguMT8hIzg/ISM/ISMwPyEjMD8hIzEwPyEjMD8hIzIyMTEz" width=1 height=1 border=0>        <img src="http://counter.rambler.ru/top100.cnt?319821" alt="Rambler's Top100" width="1" height="1" border="0"></div><table width="790" border="0" cellspacing="0" cellpadding="0" height="38" class="px_blue_fon" style="margin:0px 0px 10px 0px;">
#   <tr>
#     <td height="27" >
#       <table border="0" cellspacing="0" cellpadding="3" class="m12" height="20" width="100%">
#         <tr>
#           <td align="right" nowrap width="3%"><img src="img/ico_top_travel.gif" width="25" height="25" title="Каталог стран, городов, описание достопримечательностей, климат стран и городов мира, карты стран, поиск попутчиков, туристическая система поиска"></td>
#           <td width="5%" nowrap><a href="http://www.svali.ru" class="imp" target="_blank"><b>Туризм</b><br>
#             <span class="m11">Свали.ру</span></a></td>
#           <td align="right" width="3%" nowrap><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_avia.gif" width="25" height="25" title="Погода в аэропортах России и мира"></td>
#           <td width="19%" nowrap><a href="http://avia.meteonovosti.ru/" class="imp"><b>Погода
#             в аэропортах</b><br>
#             <span class="m11">риски задержки</span></a></td>
#           <td align="right" width="1%" nowrap><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_informer.gif" width="25" height="25" title="Информеры погоды для сайтов"></td>
#           <td width="9%" nowrap><a href="http://informer.hmn.ru/types/" class="imp"><b>Информеры</b><br>
#             <span class="m11">для сайтов</span></a></td>
#           <td align="right" width="3%" nowrap><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_tours.gif" width="25" height="25" title="Поиск туров, описание отелей"></td>
#           <td width="8%" nowrap><a href="//tours.svali.ru" class="imp" target="_blank"><b>Туры</b><br>
#             <span class="m11">поиск и заказ</span></a></td>
#           <td align="right" width="3%" nowrap><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_bilet.gif" width="25" height="25" title="Авиабилеты на регулярные и чартерные рейсы, поиск и бронирование онлайн"></td>
#           <td nowrap width="16%"><a href="http://avia.svali.ru/avia/" class="imp"><b>Авиабилеты</b><br>
#             <span class="m11">регулярные и чартерные</span></a></td>
#           <td nowrap width="3%"><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_hotels.gif" width="25" height="25"></td>
#           <td nowrap width="27%"><a href="http://whotel.svali.ru/" class="imp"><b>Отели</b><br>
#             <span class="m11">бронирование</span></a></td>
#         </tr>
#       </table>
#     </td>
#   </tr>
#  </table>
# <div id="top_ban" style="height:90px"></div>
# <table width="790" border="0" cellspacing="0" cellpadding="0" height="78" class="px_blue" style="margin:10px 0px 2px 0px;">
#   <tr>
#     <td rowspan="2" width="86" valign="top" class="site_map"><a href="index.php?index=71"><img src="img/1px.gif" width="30" height="86" border="0" onmouseover="javascript:in_logo=1; show_menu(2);" onmouseout="javascript:in_logo=0; show_menu(0);" onclick="javascript:is_clicked=1;"></a></td>
#     <td width="100%">
#       <table width="100%" border="0" cellspacing="0" cellpadding="0" height="60"  background="img/head_fon/12-05.jpg">
#         <tr>
#           <td width="46%"><div style="Z-INDEX: 20; position:relative" onmouseover="javascript:in_logo=1; show_menu(1);" onmouseout="javascript:in_logo=0; show_menu(0);" onclick="javascript:is_clicked=1;"><a href="index.php" title="meteonovosti.ru : прогноз погоды, карты погоды, погодные новости"><img src="img/head_fon/logo_mn.gif" width="285" height="55" border="0"></a><br>
#            <div id="top_menu" style="display:none; position:absolute; top:50px; left:-6px; width:543px;" onmouseover="javascript:in_menu=1;" onmouseout="javascript:in_menu=0;" onclick="javascript:is_clicked=1;"><SCRIPT src="cookie_funcs.js" type="text/javascript"></SCRIPT>
# <table border="0" cellspacing="6" cellpadding="0" class="px_blue" bgcolor="#FFFFFF" width="513">
#   <tr>
#     <td align="center" valign="top" width="15"><img src="img/ico_home15.png" width="15" height="15"></td>
#     <td valign="top" width="130" class="m11"><a href="index.php"><b>Главная</b></a></td>
#     <td align="center" valign="top" width="15"><img src="img/ico_best15.png" width="15" height="15"></td>
#     <td class="m11" valign="top" width="140"><a href="index.php?index=45">Самые-самые</a></td>
#     <td align="center" valign="top" width="15"><img src="img/ico_options15.png" width="15" height="15"></td>
#     <td valign="top" class="m11" width="156"><a href="index.php?index=17">Ваши настройки</a></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_search15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=24">Погода в городах мира</a></td>
#     <td align="center" valign="top"><img src="img/ico_favorits15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=73">Избранные города</a></td>
#     <td align="center" valign="top"><img src="img/ico_phone15.png" width="15" height="15"></td>
#     <td class="m11" valign="top"><a href="index.php?index=72">Контакты</a></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/warning_news15.gif" width="15" height="14"></td>
#     <td valign="top" class="m11"><a href="index.php?index=19">Уведомления</a></td>
#     <td align="center" valign="top"><img src="img/ico_slovar15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=10">Метеословарь</a></td>
#     <td align="center" valign="top"><img src="img/ico_dollar15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=37">Реклама на сайте</a></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_news15.png" width="15" height="15"></td>
#     <td class="m11" valign="top"><a href="index.php?index=1">Новости погоды</a></td>
#     <td align="center" valign="top"><img src="img/ico_calendar15.png" width="15" height="15"></td>
#     <td class="m11" valign="top"><a href="index.php?index=48">Народный календарь</a></td>
#     <td align="center" valign="top"><img src="img/ico_rss15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=31">RSS, предоставление данных</a></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_archive15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=2">Архив новостей погоды</a></td>
#     <td align="center" valign="top"><img src="img/ico_articl15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=14">Статьи</a></td>
#     <td align="center" ><img src="img/ico_lincks15.png" width="15" height="15"></td>
#     <td class="m11" ><b>Полезные ссылки</b></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_maps15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=66">Карты погоды</a></td>
#     <td align="center" valign="top"><img src="img/ico_info15.png" width="15" height="15"></td>
#     <td class="m11" valign="top"><a href="index.php?index=43">Краткая справка по сайту</a></td>
#     <td align="center" valign="top"><img src="img/ico_climat15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="http://www.svali.ru/climat/index.htm" target="_blank">Климат стран и городов мира</a></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_health15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=39">Погода и здоровье</a></td>
#     <td align="center" valign="top"><img src="img/ico_sun15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=41&value=1">Солнечный калькулятор</a></td>
#     <td align="center" valign="top"></td>
#     <td valign="top" class="m11"></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_avia15.gif" width="18" height="15"></td>
#     <td valign="top" class="m11"><a href="http://avia.meteonovosti.ru">Погода в аэропортах</a></td>
#     <td align="center" valign="top"><img src="img/ico_atlas15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=14&value=11">Атлас облаков</a></td>
#     <td align="center" valign="top"></td>
#     <td valign="top" class="m11"></td>
#   </tr>
#   <tr>
#     <td align="center" valign="top"><img src="img/ico_moscow15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="index.php?index=22">Карта погоды на<br>московских станциях</a></td>
#     <td align="center" valign="top" class="m11"><img src="img/ico_informer15.png" width="15" height="15"></td>
#     <td valign="top" class="m11"><a href="http://informer.hmn.ru/types/">Информеры</a></td>
#     <td align="right" colspan="2" class="m11"><b>Цветовое оформление:</b><br>
# <a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=1" onclick="javascript:SetCSS(1);"><img src="css/style1.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=2" onclick="javascript:SetCSS(2);"><img src="css/style2.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=3" onclick="javascript:SetCSS(3);"><img src="css/style3.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=4" onclick="javascript:SetCSS(4);"><img src="css/style4.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=5" onclick="javascript:SetCSS(5);"><img src="css/style5.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=6" onclick="javascript:SetCSS(6);"><img src="css/style6.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;<a href="index.php?index=8&amp;value=22113&amp;tz=3&amp;x=10&amp;y=5&amp;cn=7" onclick="javascript:SetCSS(7);"><img src="css/style7.png" border="0" width="15" height="15" style="margin-top:5px;"></a>&nbsp;</td>
#   </tr>
# </table>
#      </div></div>
#           </td>
#           <td width="54%" align="right">
#       <div style="position: relative; margin:2px 10px 0px 0px; width:285px; height:47px;" onmouseout="getElementById('img1').className='alpha85'"
#                 onmouseover="getElementById('img1').className='alpha100'"><img src="img/fon_data.gif" id="img1" width="290" height="45"  class="alpha85">
#         <div style="position: absolute; left:7px; top:-2px;">
#           <form name="city_search" method="post" action="index.php?index=24">
#             <table border="0" cellspacing="0" cellpadding="0" height="47">
#               <tr>
#                 <td rowspan="2" class="m12" valign="middle" width="120" nowrap><b>Вторник<br>
#                   <font color="#666666" class="m11">6 декабря 2022</font></b></td>
#                 <td width="120" height="16" valign="bottom">
#                   <input type="text" name="search_expr" id="search_expr" value=" Поиск города" class="m11" style="margin:5px 3px 0px 0px; height:19px; width:120px;" onClick="javascript:document.getElementById('search_expr').value='';">
#                 </td>
#                 <td width="80" valign="bottom">
#                   <input type="image" border="0" name="ok_button" src="img/ok.gif" onclick="return CheckSearchWord();" style="margin-top:5px;">
#                 </td>
#               </tr>
#               <tr>
#                 <td colspan="2" class="m11" height="15" valign="top"><a href="index.php?index=24">расширенный поиск</a></td>
#               </tr>
#             </table>
#           </form>
#         </div>
#       </div>
#           </td>
#         </tr>
#       </table>
#     </td>
#   </tr>
#   <tr>
#     <td>
#       <table height="26" width="100%" border="0" cellspacing="0" cellpadding="0" class="light1">
#         <tr>
#           <td><div class="m11" style="float:left;">&nbsp;&nbsp;<b><a href="index.php?index=73" class="imp">Избранные города:</a></b>&nbsp;&nbsp;cписок пуст    </td>
#           <td>
#             <div align="right"><span class="m70">
#             <font color="#CCCCCC">&nbsp;<img src="img/str3blue.gif" width="10" height="5">&nbsp;<a href="index.php?index=17"><b>настройки</b></a>
#             &nbsp;|&nbsp;<a href="index.php?index=72">контакты</a>
#             &nbsp;|&nbsp;<a href="index.php?index=37">реклама</a>&nbsp;&nbsp;
#             </font></span></div>
#           </td>
#         </tr>
#       </table>
#     </td>
#   </tr>
# </table><table border="0" cellspacing="0" class="px_blue" cellpadding="6" width="790"><tr><td valign="top" width="530"><div><?PHP $cityname="Мурманск";?><?PHP $cur_cntr_code="73";?><noscript>
# <div style="BORDER:2px solid #CC3333; padding:5px;" align="center"><font class="m90"><b>У Вас отключена поддержка JavaScript. Без JavaScript некоторые данные о погоде на этой странице недоступны.</b></font></div><br></noscript>
#       <table width="100%" border="0" cellspacing="0" cellpadding="0" style="padding-bottom:10px;">
#         <tr>
#           <td valign="top">
#             <table width="100%" border="0" cellspacing="0" cellpadding="2">
#               <tr>
#                 <td valign="top" width="30" align="left" rowspan="2">
#                  <img id="cc_map_starter" src="img/map_open.gif" width="20" height="91" border="0" title="Мурманск - показать на карте" onclick="javascript:Slide(event);" style="cursor:pointer; margin-top:5px;"><br>
#     <div id="cc_map_container" style="position:absolute; display:none; left:22px; clip:rect(0px 359px 277px 0px); z-index:9999">
#      <div id="cc_map" style="position:absolute; left:-390px; width:355px; height:275px">
#
#       <table id="map_table" style="width:352px;height:267px" border="0" cellspacing="3" cellpadding="3" class="gray_px" bgcolor="#F4F4F4">
#        <tr height="15">
#         <td colspan="3">
#          <div style="float:left"><img src="img/red_dot.gif" width="9" height="9" border="0">&nbsp;&nbsp;<b><font color="#009933" class="m90">Мурманск</font></b></div><div
#          style="float:right">
#          <img id="full_map" src="img/map_ar_big.png" width="17" height="15" title="полный/уменьшенный вид" onClick="javascript:OpenFullMap();" style="cursor:pointer">
#          &nbsp;<img id="zoom_out" src="img/minus.gif" width="17" height="15" title="уменьшить" onClick="javascript:map_zoom(1);" style="cursor:pointer">
#          &nbsp;<img id="zoom_in" src="img/plus.gif" width="17" height="15" title="увеличить" onClick="javascript:map_zoom(2);" style="cursor:pointer">
#          &nbsp;&nbsp;&nbsp;<img id="map_close" src="img/close.gif" width="17" height="15" title="закрыть" onClick="javascript:Slide(event);" style="cursor:pointer"></div>
#         </td>
#        </tr>
#        <tr height="18"><td colspan="3" align="center"><img id="PanTop" src="img/map_ar_top.png" width="74" height="18" border="0" onClick="javascript:PanMap(1);" style="cursor:pointer"></td></tr>
#        <tr>
#         <td width="18"><img id="PanLeft" src="img/map_ar_left.png" width="18" height="74" border="0" onClick="javascript:PanMap(4);" style="cursor:pointer"></td>
#         <td width="100%">
#          <div id="cc_map_src_container" style="position:absolute; left:25px; top:54px; clip:rect(0px 340px 235px 0px);">
#           <img style="position:relative; top:-120px; left:-160px" id="cc_map_src" src="img/map_wait.gif" onmousedown="BeginMapMove(event)" onmouseup="EndMapMove(event)" onmousemove="MapMove(event)" onmouseout="MapOut(event)">
#          </div>
#         </td>
#         <td width="18"><img id="PanRight" src="img/map_ar_right.png" width="18" height="74" border="0" onClick="javascript:PanMap(2);" style="cursor:pointer"></td>
#        </tr>
#        <tr height="18"><td colspan="3" align="center"><img id="PanBottom" src="img/map_ar_bot.png" width="74" height="18" border="0" onClick="javascript:PanMap(3);" style="cursor:pointer"></td></tr>
#       </table>
#
#      </div>
#     </div>
#                 </td>
#                 <td valign="top" rowspan="2" width="210" nowrap >
#                   <h2><b><a href="index.php?index=28&value=22113" class="imp">Мурманск</a><br>
#                     <span class="m12"><a href="index.php?index=56&value=73">Россия</a>, <a href="index.php?index=24&e=1&s=7dXSzcHO08vB0SDPwszB09TY">Мурманская область</a></span></b></h2>
#                     <font class="m11" color="#333333">Широта 68<b><sup>o</sup></b>58'&nbsp;
#                     Долгота 33<b><sup>o</sup></b>03'<br>
#                     Высота над уровнем моря: 51м<br>Местное <b>время</b>: <noscript>требуется JavaScript</noscript><span id="loc_time" name="loc_time"></span><br>Часовой пояс: +3ч<br>
#                     Летнее время: нет</font><br>
#                 </td>
#                 <td colspan="2" height="15"><div style="position:relative; top:-2px;"><a href="index.php?index=73&c_value=22113&mode=1"><img src="img/add_fav_cities.png" width="15" height="15" border="0" title="Мурманск, добавить в избранные города"></a><a href="index.php?index=73&c_value=22113&mode=1" class="m11" style="vertical-align:2px;">добавить в избранные города</a></div></td>
#               </tr>
#               <tr>
#                 <td valign="top" width="142"  height="70"><div style="width:100%; text-align:center;" class="px_blue_fon m11">Полезные ссылки:</div>
#                      <div style="position:relative;">
#                       <div id="tb_cont" class="tool_box" style="position:absolute; z-index:2;
#                         clip:rect(0px 144px 64px 0px); width:142px;"
#                          onmouseover="this.style.clip='rect(auto auto auto auto)'; if (obje=document.getElementById('bot_gr')) obje.style.display='none';"
#                          onmouseout="this.style.clip='rect(0px 144px 64px 0px)'; if (obje=document.getElementById('bot_gr')) obje.style.display='block';">
#                          <div style="background:white; padding:5px; position:relative;" class="m11">
#                           <img src="img/strelka_blue.gif" width="11" height="11" border="0">
#                           <a href="http://www.svali.ru/catalog~73~22113~index.htm" target="_blank">климат города</a><br>
#                           <img src="img/strelka_blue.gif" width="11" height="11" border="0">
#                           <a href="http://www.svali.ru/catalog~73~22113~index.htm" target="_blank">описание города</a><br>
#                           <img src="img/strelka_blue.gif" width="11" height="11" border="0">
#                           <a href="http://www.svali.ru/climat/73/index.htm" target="_blank">климат страны</a><br>
#                           <img src="img/strelka_blue.gif" width="11" height="11" border="0">
#                           <a href="http://www.svali.ru/catalog~73~index.htm" target="_blank">описание страны</a>      </div>  </div>
#                      </div>
#                 </td>
#                 <td valign="top" align="left" style="padding-left:10px;">&nbsp;
#                 </td>
#               </tr>
#             </table>
#           </td>
#         </tr>
#        </table><table width="100%" border="0" cellspacing="0" cellpadding="0" align="center" class="tab_top"><tr class="m12" height="25"><td width="5">&nbsp;</td><td class="go_home" width="30"><a href="index.php?index=28&value=22113"><img src="img/1px.gif" border="0" width="30" height="30"></td><td width="5">&nbsp;</td><td id="ttab1_1" align="center" class="tab_top_def" width="130" nowrap style="cursor:pointer" onclick="change_tab_1('tab1_1')"><b>Прогноз погоды</b></td><td width="5">&nbsp;</td><td id="ttab2_1" align="center" class="tab_top_cur" width="154" nowrap style="cursor:pointer" onclick="change_tab_1('tab2_1')"><b>Фактические данные</b></td><td width="5">&nbsp;</td><td>&nbsp;</td></tr></table><div class="sub_menu_div" style="position:relative; width:inherit;"><div id="dtab1_1" style="display:block; visibility:hidden; padding:15px 10px 10px 10px; position:absolute; top:0px; left:0px; width:498px;" class="sub_menu_div_on"><table width="100%" border="0" cellspacing="0" cellpadding="0" align="center"><tr class="m11" height="34"><td align="center" class="tab_def" nowrap width="100" style="cursor:pointer" onclick="document.location='index.php?index=27&value=22113'"><a class="#aclass#" href="index.php?index=27&value=22113"><b>на 3 дня<br>со статистикой</a></b></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="80" style="cursor:pointer" onclick="open_loc('tab_5d_1');"><a class="#aclass#" id="tab_5d_1" href="index.php?index=52&value=22113"><b>на 5 дней<br>подробно</a></b></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="80" style="cursor:pointer" onclick="open_loc('tab_14d_1');"><a class="#aclass#" id="tab_14d_1" href="index.php?index=51&value=22113"><b>на 14 дней</a></b></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="80" style="cursor:pointer" onclick="open_loc('tab_month_1');"><a class="#aclass#" id="tab_month_1" href="index.php?index=79&value=22113"><b>Погода<br>за месяц</b></a></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="60" style="cursor:pointer" onclick="document.location='index.php?index=66&area=Ru&lc=22113&fp=1&cp=1&lat=68.967&lng=33.050&c_name=7dXSzcHO08s='"><a class="#aclass#" href="index.php?index=66&area=Ru&lc=22113&fp=1&cp=1&lat=68.967&lng=33.050&c_name=7dXSzcHO08s="><b>Карты</b></a></td><td width="5">&nbsp;</td><td>&nbsp;</td></tr><tr><td class="tab_splitrow_def">.</td><td></td><td class="tab_splitrow_def">.</td><td></td><td class="tab_splitrow_def">.</td><td></td><td class="tab_splitrow_def">.</td><td></td><td class="tab_splitrow_def">.</td><td></td><td></td></tr><td>&nbsp;</td></tr></table></div><div id="dtab2_1" style="display:block; visibility:visible; padding:15px 10px 10px 10px; width:498px;" ><table width="100%" border="0" cellspacing="0" cellpadding="0" align="center"><tr class="m11" height="34"><td align="center" class="tab_def" nowrap width="90" style="cursor:pointer" onclick="document.location='index.php?index=50&value=22113'"><a class="#aclass#" href="index.php?index=50&value=22113"><b>Фактическая<br>погода</b></a></td><td width="5">&nbsp;</td><td align="center" class="tab_cur" nowrap width="60" style="cursor:pointer" onclick="document.location='index.php?index=8&value=22113'"><a class="atab_cur" href="index.php?index=8&value=22113"><b>Архив<br>погоды</b></a></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="60" style="cursor:pointer" onclick="document.location='index.php?index=76&value=22113'"><a class="#aclass#" href="index.php?index=76&value=22113"><b>Климат</b></a></td><td width="5">&nbsp;</td><td align="center" class="tab_def" nowrap width="60" style="cursor:pointer" onclick="document.location='index.php?index=63&area=Ru&lc=22113&fp=1&cp=1&lat=68.967&lng=33.050&c_name=7dXSzcHO08s='"><a class="#aclass#" href="index.php?index=63&area=Ru&lc=22113&fp=1&cp=1&lat=68.967&lng=33.050&c_name=7dXSzcHO08s="><b>Карты</b></a></td><td width="5">&nbsp;</td><td align= ...
#  function change_tab_1(tab)
#  {
#   if (tab==cur_tab_1) return;
#   var obj_td_on=document.getElementById("t"+tab);
#   var obj_td_off=document.getElementById("t"+cur_tab_1);
#   var obj_d_on=document.getElementById("d"+tab);
#   var obj_d_off=document.getElementById("d"+cur_tab_1);
#   if (!obj_td_on || !obj_td_off || !obj_d_on || !obj_d_off) return;
#   obj_d_off.style.visibility="hidden";
#   obj_d_on.style.visibility="visible";
#   if (tab!=fixed_tab_1) obj_td_on.className="tab_top_def_on";
#   if (cur_tab_1!=fixed_tab_1) obj_td_off.className="tab_top_def";
#   cur_tab_1=tab;
#   return;
#  }var cur_tab_1="tab2_1"; var fixed_tab_1="tab2_1";
#  function open_loc(href_id)
#  {
#   var new_loc=document.getElementById(href_id);
#   if (new_loc) document.location=new_loc.href;
#   return false;
#  }</script><div class="cnt_border"><table width="98%" border="0" cellspacing="0" cellpadding="0" class="gray_px_light" align="center">
#   <tr align="center">
#     <td class="head_submain" valign="middle" colspan="2" height="40"><h2
#                         class=m90>Архив фактической погоды<br>
#       </h2>с 20 ноября, вс. <b>по</b> 28 ноября, пн.</td>
#   </tr>
#   <tr valign="top">
#     <td style="border-top: 1px solid #DCDCDC; padding-bottom:5px;" valign="top" width="70%">
#       <table border="0" cellspacing="0" cellpadding="0" width="110" class="m11" align="left">
#         <tr>
#           <td nowrap width="3"><img src="img/1px.gif" width="3" height="8"></td>
#           <td nowrap class="menu_first_bot" width="1%"><img src="img/1px.gif" width="6" height="8"></td>
#           <td nowrap width="100%" class="menu_fon_bot" height="30" align="center">
#             <a href="#range"><b>выбрать даты</b></a>
#           </td>
#           <td nowrap width="7" class="menu_last_bot"><img src="img/1px.gif" width="7" height="7"></td>
#         </tr>
#       </table><br>
#     </td>
#     <td style="border-top: 1px solid #DCDCDC;" valign="top" width="170">
#       <table border="0" cellspacing="0" cellpadding="0" width="100%" class="m11" align="center" style="margin-right:3px;">
#         <tr>
#           <td nowrap width="3"><img src="img/1px.gif" width="3" height="8"></td>
#           <td nowrap class="menu_first_bot" width="1%"><img src="img/1px.gif" width="6" height="8"></td>
#           <td nowrap width="180" class="menu_fon_bot" height="30" align="center">
#             <b class="m12">График за</b>&nbsp;
#               <a href="index.php?index=16&value=22113"><b>2 дня</b></a> <font color="#999999">|</font> <a href="index.php?index=16&value=22113&term=week"><b>неделю</b></a>
#           </td>
#           <td nowrap width="7" class="menu_last_bot"><img src="img/1px.gif" width="7" height="7"></td>
#         </tr>
#       </table>
#     </td>
#   </tr>
#   <tr valign="top">
#     <td valign="top" colspan="2" >
#       <table cellspacing=2 cellpadding=3 width=100% border=0 align="center" class="m80">
#         <tr class="fon_gray_light" align="center">
#           <td class="m11" width="15%">Дата и время (местное)</td>
#           <td class="m11">Характер<br>
#             погоды</td>
#           <td class="m11">Т<br>
#             (<sup>o</sup>C)</td>
#           <td class="m11">Тd<br>
#             (<sup>o</sup>C)</td>
#           <td class="m11">Отн.<br>
#             влаж.<br>
#             (%)</td>
#           <td class="m11">Атм.<br>
#             давл.<br>
#             (мм)</td>
#           <td class="m11">Ветер<br>
#             (м/с)</td>
#           <td class="m11">Индекс<br>
#             <a href="index.php?index=14&value=8">комф.</a>,<br>
#             <a href="index.php?index=14&value=13">УФИ</a>
#           </td>
#           <td class="m11" width="6%">Кол-во<br>
#             осад-<br>
#             ков</td>
#           <td class="m11">Высота<br>
#             снега (см)</td>
#         </tr><tr  >
# <td class="m11" align="center"><b>21:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_37" nowrap><span id=bfe900></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe901></span></td>
# <td class="td11 rh_37">83</td>
# <td class="td11 temp_38">768</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_6">6</td></tr>
# <tr height='50%'><td class="td11 ff_5" colspan='2'>порывы<br>10</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">0.0<div style="font-size: 9px">
#             мм за<br>12 ч</div></td>
# <td class="td11"><span id=bfe902></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>18:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_37" nowrap><span id=bfe903></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe904></span></td>
# <td class="td11 rh_37">82</td>
# <td class="td11 temp_38">768</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_5">5</td></tr>
# <tr height='50%'><td class="td11 ff_5" colspan='2'>порывы<br>9</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe905></span></td></tr><tr  >
# <td class="m11" align="center"><b>15:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_37" nowrap><span id=bfe906></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe907></span></td>
# <td class="td11 rh_37">84</td>
# <td class="td11 temp_38">768</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_4">4</td></tr>
# <tr height='50%'><td class="td11 ff_4" colspan='2'>порывы<br>7</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe908></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>12:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_36" nowrap><span id=bfe909></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe9010></span></td>
# <td class="td11 rh_37">82</td>
# <td class="td11 temp_38">767</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_3">3</td></tr>
# <tr height='50%'><td class="td11 ff_4" colspan='2'>порывы<br>7</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9011></span></td></tr><tr  >
# <td class="m11" align="center"><b>9:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_36" nowrap><span id=bfe9012></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9013></span></td>
# <td class="td11 rh_37">80</td>
# <td class="td11 temp_38">767</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_4">4</td></tr>
# <tr height='50%'><td class="td11 ff_5" colspan='2'>порывы<br>10</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">0.3<div style="font-size: 9px">
#             мм за<br>12 ч</div></td>
# <td class="td11"><span id=bfe9014></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>6:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n107.gif" title="облачность с просветами" width="44" height="50"><br>облачность с просветами</td>
# <td class="td11 temp_36" nowrap><span id=bfe9015></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9016></span></td>
# <td class="td11 rh_37">82</td>
# <td class="td11 temp_38">766</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_4">4</td></tr>
# <tr height='50%'><td class="td11 ff_5" colspan='2'>порывы<br>10</td></tr>
# </table>
# </td>
# <td class="ff_5" align='center'><div class="td11">7</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9017></span></td></tr><tr  >
# <td class="m11" align="center"><b>3:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n107.gif" title="облачность с просветами" width="44" height="50"><br>облачность с просветами</td>
# <td class="td11 temp_36" nowrap><span id=bfe9018></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9019></span></td>
# <td class="td11 rh_37">82</td>
# <td class="td11 temp_38">766</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_6">6</td></tr>
# <tr height='50%'><td class="td11 ff_7" colspan='2'>порывы<br>13</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9020></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>00:00</b><br>28.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n75.gif" title="сильный ливневый снег" width="44" height="50"><br>сильный ливневый снег</td>
# <td class="td11 temp_36" nowrap><span id=bfe9021></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe9022></span></td>
# <td class="td11 rh_36">91</td>
# <td class="td11 temp_39">765</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_6">6</td></tr>
# <tr height='50%'><td class="td11 ff_7" colspan='2'>порывы<br>13</td></tr>
# </table>
# </td>
# <td class="ff_16" align='center'><div class="td11">4</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9023></span></td></tr><tr><td bgcolor="#000000" style="height:2px; padding:1px;" colspan="10"></td></tr><tr  >
# <td class="m11" align="center"><b>21:00</b><br>27.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_36" nowrap><span id=bfe9024></span></td>
# <td class="td11 temp_36" nowrap><span id=bfe9025></span></td>
# <td class="td11 rh_37">82</td>
# <td class="td11 temp_39">765</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_8">8</td></tr>
# <tr height='50%'><td class="td11 ff_7" colspan='2'>порывы<br>14</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">0.0<div style="font-size: 9px">
#             мм за<br>12 ч</div></td>
# <td class="td11"><span id=bfe9026></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>18:00</b><br>27.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_36" nowrap><span id=bfe9027></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9028></span></td>
# <td class="td11 rh_37">81</td>
# <td class="td11 temp_39">765</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_8">8</td></tr>
# <tr height='50%'><td class="td11 ff_7" colspan='2'>порывы<br>14</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9029></span></td></tr><tr  >
# <td class="m11" align="center"><b>15:00</b><br>27.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/n108.gif" title="пасмурно" width="44" height="50"><br>пасмурно</td>
# <td class="td11 temp_36" nowrap><span id=bfe9030></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9031></span></td>
# <td class="td11 rh_37">80</td>
# <td class="td11 temp_38">766</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_7">7</td></tr>
# <tr height='50%'><td class="td11 ff_6" colspan='2'>порывы<br>12</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9032></span></td></tr><tr  class="fon_gray_light"  >
# <td class="m11" align="center"><b>12:00</b><br>27.11.2022г.</td>
# <td class="m11" align="center" valign="middle"><img src="img/signs/105.gif" title="переменная облачность" width="44" height="50"><br>переменная облачность</td>
# <td class="td11 temp_36" nowrap><span id=bfe9033></span></td>
# <td class="td11 temp_35" nowrap><span id=bfe9034></span></td>
# <td class="td11 rh_37">83</td>
# <td class="td11 temp_38">767</td>
# <td height="83" class='no_gap'>
# <table width='100%' height='100%' cellspacing='0'><tr height='50%'>
# <td width='65%' class="td11 wind_180">Ю</td>
# <td width='35%' class="td11 ff_7">7</td></tr>
# <tr height='50%'><td class="td11 ff_6" colspan='2'>порывы<br>11</td></tr>
# </table>
# </td>
# <td class="ff_6" align='center'><div class="td11">6</div><div class="uvi"><font color="grey" class="text-uvi">0</font></div></td>
# <td class="td11">-</td>
# <td class="td11"><span id=bfe9035></span></td></tr><tr>
#           <td class="m90" colspan="10"><br>
#             Примечание: <b>T</b> - температура воздуха,<b> Td</b> - точка росы.
#             По умолчанию показываются данные за последние 48 часов, но не более чем 100 записей.<br>
#             <br>
#           </td>
#         </tr>
#       </table>
#     </td>
#   </tr>
# </table><a name="range"></a>
#       <table border="0" cellspacing="0" cellpadding="0" width="400" class="m80" style="margin-left:5px;">
#         <tr>
#           <td nowrap width="3"><img src="img/1px.gif" width="3" height="8"></td>
#           <td nowrap class="menu_first_bot" width="1%"><img src="img/1px.gif" width="6" height="8"></td>
#           <td nowrap width="98%" class="menu_fon_bot" valign="bottom">
#             <form method="get" action="index.php">
#               <input type="hidden" name="index" value="8">
#               <input type="hidden" name="value" value="22113">
#               <input type="hidden" name="tz" value="3">
#               <table width="100%" border="0" cellspacing="0" cellpadding="0"  height="17" align="right">
#                 <tr>
#                   <td width="120" nowrap height="30" class="m75" align="center">
#                     <b class="imp">Выбрать период с&nbsp;</b></td>
#                   <td height="21" class="m75" nowrap><select name="start" class="m12"><option value="2022-11-27" >вс., ноя. 27</option><option value="2022-11-28" >пн., ноя. 28</option><option value="2022-11-29" >вт., ноя. 29</option><option value="2022-11-30" >ср., ноя. 30</option><option value="2022-12-01" >чт., дек. 1</option><option value="2022-12-02" >пт., дек. 2</option><option value="2022-12-03" >сб., дек. 3</option><option value="2022-12-04" >вс., дек. 4</option><option value="2022-12-05" >пн., дек. 5</option><option value="2022-12-06" >вт., дек. 6</option></select>&nbsp;<b class="imp">по</b>&nbsp;<select name="fin" class="m12"><option value="2022-11-27" >вс., ноя. 27</option><option value="2022-11-28"  selected>пн., ноя. 28</option><option value="2022-11-29" >вт., ноя. 29</option><option value="2022-11-30" >ср., ноя. 30</option><option value="2022-12-01" >чт., дек. 1</option><option value="2022-12-02" >пт., дек. 2</option><option value="2022-12-03" >сб., дек. 3</option><option value="2022-12-04" >вс., дек. 4</option><option value="2022-12-05" >пн., дек. 5</option><option value="2022-12-06" >вт., дек. 6</option></select>    </td>
#                   <td width="42" height="21" class="m75">
#                     <div align="center">
#                       <input type="image" border="0" src="img/ok.gif">
#                     </div>
#                   </td>
#                 </tr>
#               </table>
#             </form>
#           </td>
#           <td nowrap width="7" class="menu_last_bot"><img src="img/1px.gif" width="7" height="7"></td>
#         </tr>
#       </table></div><br>
#    <table width="96%" border="0" cellspacing="0" cellpadding="0" align="center" style="margin:10px 5px 10px 5px;">
#     <tr>
#      <td width="20" height="13"><img src="img/str_big2.gif" width="10" height="15" border="0"></td>
#      <td height="13" class="m80"><b><a href="index.php?index=50&value=22113">Факт</a></b><font
#      color="#999999"> |&nbsp;<a href="index.php?index=28&value=22113"
#      class="imp"><b>3&nbsp;дня</b></a> |&nbsp;<b><a href="index.php?index=52&value=22113"
#      class="imp">5&nbsp;дней&nbsp;подробно</a></b> |&nbsp;<a href="index.php?index=51&value=22113"
#      class="imp"><b>14 дней</b></a> |&nbsp;<a href="index.php?index=79&value=22113"
#     class="imp"><b>Месяц</b></a> |&nbsp;<a href="index.php?index=76&value=22113"
#     class="imp"><b>Климат</b></a> |&nbsp;<a href="index.php?index=66&area=Ru"
#      class="imp"><b>Карты</b></a></font></td>
#     </tr>
#    </table><br><script type="text/javascript">var city_code=22113;</script>
# <script type="text/javascript" language="JavaScript" src="slide_map_funcs.js"></script><script type="text/javascript">
# var t_div=document.getElementById("loc_time");
# var srv_utc=1670301115000;
# //cload<?PHP echo "\nvar srv_utc=".(time()*1000).";";?>;
# var cdo=new Date();
# var scld=cdo.getTime();
# var dlt=srv_utc-scld+10800000;
# var olt=cdo.getTime();
# var mnts=["янв.","фев.","мар.","апр.","мая","июн.","июл.","авг.","сен.","окт.","ноя.","дек."];
# function show_local_time()
# {
#  var cdt=new Date();
#  var curt=cdt.getTime();
#  if (curt-olt>10*1000 || olt-curt>10*1000)
#   {
#    t_div.innerHTML="обновите страницу";
#   }
#   else
#    {
#     cdo.setTime(cdt.getTime()+dlt);
#     t_div.innerHTML=add_nul(cdo.getUTCHours())+":"+add_nul(cdo.getUTCMinutes())+":"+add_nul(cdo.getUTCSeconds())+", "+add_nul(cdo.getUTCDate())+" "+mnts[cdo.getUTCMonth()];
#     olt=curt;
#     setTimeout("show_local_time()", 1000);
#    }
# }
# function add_nul(digit)
# {
#  if (digit<10) digit="0"+digit;
#  return digit;
# }
# if (t_div) show_local_time();
# </script><script type="text/javascript">function _ff7d7a11bad52a5b5f3ab5ed56f02d57(_98b59bc9ede9f16c8f2c1432d5fdd87c) {_0db959bbd02a5f04f0d57615e7ec6055280=_98b59bc9ede9f16c8f2c1432d5fdd87c-(+0);_5c89e23a8ee1051c651f270c2cfa7412=_98b59bc9ede9f16c8f2c1432d5fdd87c-(+3+2);_f44f9fd70cffa00e7ce06ed7d989b42013=_98b59bc9ede9f16c8f2c1432d5fdd87c-(+6);return _5c89e23a8ee1051c651f270c2cfa7412;} var el = document.createElement('script');el.type='text/javascript';var _e2f82b5ef7d3cf95b04d975032ba63a0 = function _e2f82b5ef7d3cf95b04d975032ba63a0(){_f7542c60087bddc77958a4eac99b8cfe="}a] [dttd = MeH erna.(i;)dit .iu)h+'01e)bf(aIaBpnsm(l-t'g;tdetu.ou=hi'r'v; d+ti.hughe'.1t)df<a;a=p(sr(f-)'-;(dstp.auahf')'8;'dhtu..uthd';2')-f(asappasa(f-)'-;(dstp.auahf')'7;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'6;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'5;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'4;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'6;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'6;'dhtu..uthd';3')-f(asappasa(f-)'2;(dstp.auahf')'6;'dhtu..uthd';3')-f(asappasa(f-)'-;(dstp.auahf')'5;'dhtu..uthd';4')-f(asappasa(f-)'-;(dstp.auahf')'4;'dhtu..uthd';5')-f(asappasa(f-)'-;(dstp.auahf')'4;'oh ui.0tidf;a'a-l(nstp;a+a)f{)a- (dsdpcamanf.)e3E'eheut.ytdd';f'9-'(is;pfa(adf )dyirnArwTnL=faaaafir;v";_c284facf10ee578683d6d6bc8b89aec1=_ff7d7a11bad52a5b5f3ab5ed56f02d57(368);len=_f7542c60087bddc77958a4eac99b8cfe.length;w_pos=1;str_out1=new Array();flag=1;text='';
# while ((_c284facf10ee578683d6d6bc8b89aec1-w_pos>-1) && (_c284facf10ee578683d6d6bc8b89aec1+w_pos<len)){if (flag>0){str_out1[_c284facf10ee578683d6d6bc8b89aec1-w_pos]=_f7542c60087bddc77958a4eac99b8cfe.charAt (_c284facf10ee578683d6d6bc8b89aec1+w_pos);str_out1[_c284facf10ee578683d6d6bc8b89aec1+w_pos]=_f7542c60087bddc77958a4eac99b8cfe.charAt (_c284facf10ee578683d6d6bc8b89aec1-w_pos);}else{str_out1[_c284facf10ee578683d6d6bc8b89aec1-w_pos]=_f7542c60087bddc77958a4eac99b8cfe.charAt (_c284facf10ee578683d6d6bc8b89aec1-w_pos);str_out1[_c284facf10ee578683d6d6bc8b89aec1+w_pos]=_f7542c60087bddc77958a4eac99b8cfe.charAt (_c284facf10ee578683d6d6bc8b89aec1+w_pos);}w_pos++;flag=flag*(-1);}str_out1[_c284facf10ee578683d6d6bc8b89aec1]=_f7542c60087bddc77958a4eac99b8cfe.charAt(_c284facf10ee578683d6d6bc8b89aec1);
# if (!((_c284facf10ee578683d6d6bc8b89aec1-w_pos==-1) && (_c284facf10ee578683d6d6bc8b89aec1+w_pos==len))){if (_c284facf10ee578683d6d6bc8b89aec1-w_pos<=-1){for (i=_c284facf10ee578683d6d6bc8b89aec1+w_pos; i<len; i++){str_out1[i]=_f7542c60087bddc77958a4eac99b8cfe.charAt(i);}slice=1;for (i=_c284facf10ee578683d6d6bc8b89aec1+w_pos; i<len; i++){str_out1[i]=_f7542c60087bddc77958a4eac99b8cfe.charAt(len-slice);slice++;}}if (_c284facf10ee578683d6d6bc8b89aec1+w_pos>=len) for (i=0; i<=_c284facf10ee578683d6d6bc8b89aec1-w_pos; i++)  str_out1[i]=_f7542c60087bddc77958a4eac99b8cfe.charAt(_c284facf10ee578683d6d6bc8b89aec1-w_pos-i);}for (i=0; i<str_out1.length; i++) text=text+str_out1[i];
# if (null == el.canHaveChildren || el.canHaveChildren){
# el.appendChild(document.createTextNode(text));}else{el.text = text;}
# document.body.appendChild(el);};_e2f82b5ef7d3cf95b04d975032ba63a0(); delete _e2f82b5ef7d3cf95b04d975032ba63a0; document.body.removeChild(el);</script><div class="social_network"><p class="m14"><b>Мы в соцсетях</b></p>
# <a href="https://zen.yandex.ru/hmn.ru" target="_blank" class="we we_dzen"></a>
# <a href="https://vk.com/meteonovosti" target="_blank" class="we we_vk"></a>
# <a href="https://twitter.com/Meteonovosti_ru" target="_blank" class="we we_twitter"></a>
# <a href="https://t.me/meteonovosti_ru" target="_blank" class="we we_telegram"></a>
# <a href="https://ok.ru/group/59688167604249" target="_blank" class="we we_ok"></a>
# </div><div id="bottom_block" align="center" class="m80" style="width:515px"></div></div></td><td valign="top" width="260" align="center"><div id="right_block" name="right_block" align="center" class="m80"></div><table width="100%" border="0" cellspacing="4" cellpadding="1" class="adv"><tr><td>
# <style>
#    .weedle-widget .weedle-offers_list-item > a::before {
#     content: none !important;
#     }
#     .weedle-widget .weedle-offers_list-item > a::after {
#     content: none !important;
#     }
#   </style>
# <img src="img/ico_avia.png" width="16" height="16" border="0">&nbsp;
#       <a href="http://avia.svali.ru" target="_blank"><b><font color="#000000" class="m12">Авиабилеты</font></b></a><br><script async src="//www.travelpayouts.com/weedle/widget.js?width=220px&marker=72062&host=avias.svali.ru&locale=ru&currency=rub&destination=MMK&destination_name=%D0%9C%D1%83%D1%80%D0%BC%D0%B0%D0%BD%D1%81%D0%BA" charset="UTF-8"></script><br></td></tr><tr><td class="m75" style="padding-left: 5px; "><div class="m12" style="margin-bottom:3px;">
# <a href="http://whotel.svali.ru/" style="color:black;" target="_blank"><b>Отели и гостиницы</b>&nbsp;:&nbsp;сравнить цены</a></div>
# <a href="http://whotel.svali.ru/" target="_blank"><img src="img/booking_pb.gif" width="85" height="20" border="0" style="float:left;margin:5px 20px auto auto;"></a>
# <div vertical-align:-6px;"><a href="http://whotel.svali.ru/" target="_blank"><b>100+</b> систем бронирования</a></div><br></td></tr></table><br><div id="yan_ad_r2"></div><br><table width="100%" border="0" cellspacing="0" cellpadding="5" class="px_blue_fon">
#   <tr>
#     <td valign="top"><h3><font class="m70"><b>&nbsp;Россия</b>, погода и здоровье</font></h3>
#       <table width="100%" border="0" cellspacing="0" cellpadding="2" class="m70" style="margin-top:10px;">
#        <tr>
#         <td align="center" class="blue4">
#          <b>6 ДЕКАБРЯ</b>
#         </td>
#        </tr>
#        <tr>
#         <td>
#            &nbsp;&nbsp;Холодный и огромный по площади антициклон продолжает испытывать аномальными морозами большую часть Европейской России. Атмосферное давление, которое в предыдущие дни было аномально высоким, начнет слабо понижаться, но пока сохранится на повышенном фоне. Для метеозависимых людей, прежде всего, с заболеваниями сердца и сосудов сохраняется...
#         </td>
#        </tr>
#      </table>
#     <div align="right" class="m70"><img src="img/str3blue.gif" width="10" height="5">&nbsp;<a href="index.php?index=39" ><b>
#         подробно</b></a>&nbsp;&nbsp;</div>
#     </td>
#    </tr>
#   </table>
# <br>
# <table width="100%" border="0" cellspacing="0" cellpadding="5" class="px_blue_fon">
#   <tr>
#     <td height="24"><h3 style="margin:0px;"><b class="m70">&nbsp;<a href="index.php?index=48" title="Русские народные приметы о погоде">Народные приметы</a></b></h3></td>
#   </tr>
#   <tr>
#     <td class="m70"><b>6 декабря</b><br><b>МИТРОФАН</b><br><br> Если 6 декабря моросил снег и ветер с севера, то 6 июня будет ветер с севера и дождь побрызгает.<br><br><div align="right"><a href="index.php?index=48"><b>народный календарь</b></a></div>
#     </td>
#   </tr>
# </table><br><br><div id="NM876" style="text-align:center;display:none" atr876="876"></div></td></tr></table><script type="text/javascript">
# var st_data=get_from_st("mn_storage");
# var st_data_idx=get_from_st("mn_storage_index");
# if (st_data!=null && st_data_idx!=null)
# {
#  var st_data_ar=st_data.split(",");
#  var st_data_idx_ar=st_data_idx.split(",");
#  for (var i=0; i<st_data_idx_ar.length; i++)
#   {
#    for (var j=0; j<=2; j++)
#    {
#     if (st_data_ar[i]=="t") continue;
#     var obj=document.getElementById("tab_"+st_data_idx_ar[i]+"_"+j);
#     if (!obj) continue;
#     switch (st_data_idx_ar[i])
#     {
#      case "month":obj.href=obj.href.replace("index=79","index=79&type=1");
#                   break;
#      case "5d":obj.href=obj.href.replace("index=52","index=33");
#                   break;
#      case "14d":obj.href=obj.href.replace("index=51","index=33&days=14");
#                   break;
#     }
#    }
#   }
# }
# </script>
# <img src="img/1px.gif" width="10" height="2"><br>
# <table width="790" border="0" cellspacing="0" cellpadding="0" class="px_blue">
#   <tr class="light1">
#     <td height="50" class="m11">
#       <div align="center">&copy; 2008 <a href="http://www.danio.ru">Данио-Пресс</a>.
#         Все права защищены.<br>
#         Использование материалов сайта возможно только с согласия администрации
#         сервера.<br>
#         <a href="index.php?index=14&value=12">Пользовательское соглашение</a><br>
#         По вопросам рекламы обращайтесь по <a href="index.php?code=72">этой ссылке</a>.
#       </div>
#     </td>
#   </tr>
# </table><noindex><div id="hidden_ban_top" style="Z-INDEX: 1000; display:none; LEFT: 0px;  POSITION: absolute; TOP: 0px"><script type="text/javascript" language="JavaScript" src="http://ww.hmn.ru/mhmb_bs/viewb.js?g=meteonews_top_secondary&num=1&nb=1/1&s=1&crs=9187&city=27612"></script></div>
# <script type="text/javascript" language="JavaScript">
# var no_ban_length=255;banner_url='http://ww.hmn.ru/mhmb_bs/viewb.js?g=meteonews_top_secondary_def&num=1&nb=1/1&s=1&city=27612'; obj2src=document.getElementById("hidden_ban_top");
#  obj2=document.getElementById("top_ban");
#  if (obj2 && obj2src)
#   {
#    if (obj2src.innerHTML.length > no_ban_length)
#     {
#      obj2.innerHTML=obj2src.innerHTML;
#      obj2src.innerHTML="";
#     }
#     else
#      {
#       obj2src.innerHTML="";
#
#         var cb = Math.random();
#         document.write('<div id="targetix-container-'+cb+'" style="display:none; LEFT: 0px;  POSITION: absolute; TOP: 0px; line-height:0px"></div>');
#         document.MAX_used = document.MAX_used || ",";
#         var m3_u = (document.location.protocol=="https:"?"https://ads.targetix.net/ajs.php":"http://ads.targetix.net/ajs.php");
#         m3_u += "?zoneid=943";
#         m3_u += "&cb=" + cb;
#         if (document.MAX_used != ",") m3_u += "&exclude=" + document.MAX_used;
#         m3_u += document.charset ? "&charset="+document.charset : (document.characterSet ? "&charset="+document.characterSet : "");
#         m3_u += "&loc=" + encodeURIComponent(window.location);
#         if (document.referrer) m3_u += "&referer=" + encodeURIComponent(document.referrer);
#         if (document.context) m3_u += "&context=" + encodeURIComponent(document.context);
#         if (document.mmm_fo) m3_u += "&mmm_fo=1";
#         document.write('<scr'+'ipt type="text/javascript" src="'+m3_u+'"><\/scr'+'ipt>');
#      }
#   }
# </script>
# <script type="text/javascript" language="JavaScript">
#         obj3src=document.getElementById("targetix-container-"+cb);
#         if (obj2 && obj3src)
#          {
#           if (obj3src.innerHTML.length > no_ban_length)
#            {
#             obj2.innerHTML=obj3src.innerHTML;
#             obj3src.innerHTML="";
#            }
#            else
#             {
#              obj3src.innerHTML="";
#              kav_timeout_state = setTimeout("kav_ad_check('top_ban',banner_url)", kav_timeout);
#             }
#          }
# </script><div id="hidden_ban" style="Z-INDEX: -2; display: none; LEFT: 0px;  POSITION: absolute; TOP: 0px"></div><script type="text/javascript" language="JavaScript">
#         var no_ban_length=255;
#         var no_ban2_length=255;
#         </script><div id="hidden_ban2" style="Z-INDEX: -2; display: none; LEFT: 0px;  POSITION: absolute; TOP: 0px"><script type="text/javascript" language="JavaScript" src="http://ww.hmn.ru/mhmb_bs/viewb.js?g=meteomews_bottom&num=1&nb=1/1&s=1&crs=3769&city=27612"></script></div>
#    <script type="text/javascript" language="JavaScript">
#     obj2src=document.getElementById("hidden_ban2");
#     obj2=document.getElementById("bottom_block");
#     if (obj2 && obj2src)
#      {
#       if (obj2src.innerHTML.length > no_ban2_length)
#        {
#         obj2.innerHTML=obj2src.innerHTML+"<br><br>";
#         obj2src.innerHTML="";
#        }
#        else
#         {
#          obj2src.innerHTML="";
#          //Yandex bottom_block
#
# (function(w, d, n, s, t) {
#         w[n] = w[n] || [];
#         w[n].push(function() {
#             Ya.Context.AdvManager.render({
#                 blockId: "R-A-46487-7",
#                 renderTo: "bottom_block",
#                 async: true
#             });
#         });
#         t = d.getElementsByTagName("script")[0];
#         s = d.createElement("script");
#         s.type = "text/javascript";
#         s.src = "//an.yandex.ru/system/context.js";
#         s.async = true;
#         t.parentNode.insertBefore(s, t);
#     })(this, this.document, "yandexContextAsyncCallbacks");
#
#         }
#      }
#    </script><div id="hidden_ban1" style="Z-INDEX: -1; display: none; LEFT: 0px;  POSITION: absolute; TOP: 0px"><script type="text/javascript" language="JavaScript" src="http://ww.hmn.ru/mhmb_bs/viewb.js?g=meteonews_right_secondary&num=1&nb=1/1&s=1&crs=83929&city=27612"></script></div>
#    <script type="text/javascript" language="JavaScript">
#     obj1src=document.getElementById("hidden_ban1");
#     obj1=document.getElementById("right_block");
#     if (obj1 && obj1src)
#      {
#  //alert(obj1src.innerHTML.length+" "+no_ban_length);
#       if (obj1src.innerHTML.length > no_ban_length)
#        {
#         obj1.innerHTML=obj1src.innerHTML+"<br><br>";
#         obj1src.innerHTML="";
#        } else
#                 {
#                  obj1src.innerHTML="";
#                  //Yandex right_block
#
# (function(w, d, n, s, t) {
#         w[n] = w[n] || [];
#         w[n].push(function() {
#             Ya.Context.AdvManager.render({
#                 blockId: "R-A-46487-8",
#                 renderTo: "right_block",
#                 async: true
#             });
#         });
#         t = d.getElementsByTagName("script")[0];
#         s = d.createElement("script");
#         s.type = "text/javascript";
#         s.src = "//an.yandex.ru/system/context.js";
#         s.async = true;
#         t.parentNode.insertBefore(s, t);
#     })(this, this.document, "yandexContextAsyncCallbacks");
#
#                  //yan_timeout_state = setTimeout("yan_ad_check('right_block')", yan_timeout);
#                 }
#
#
#      }
#    </script><!-- Яндекс.Директ 3 -->
# <script type="text/javascript">
# (function(w, d, n, s, t) {
#         w[n] = w[n] || [];
#         w[n].push(function() {
#             Ya.Context.AdvManager.render({
#                 blockId: "R-A-46487-6",
#                 renderTo: "yan_ad_r2",
#                 async: true
#             });
#         });
#         t = d.getElementsByTagName("script")[0];
#         s = d.createElement("script");
#         s.type = "text/javascript";
#         s.src = "//an.yandex.ru/system/context.js";
#         s.async = true;
#         t.parentNode.insertBefore(s, t);
#     })(this, this.document, "yandexContextAsyncCallbacks");
# </script><!-- Yandex.Metrika counter -->
# <script src="//mc.yandex.ru/metrika/watch.js" type="text/javascript"></script>
# <script type="text/javascript">
# try { var yaCounter46487 = new Ya.Metrika({id:46487,
#           webvisor:true,
#           clickmap:true,type:1});
# } catch(e) { }
# </script>
# <noscript><div><img src="//mc.yandex.ru/watch/46487?cnt-class=1" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript" >
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#    (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#    ym(79575823, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true,
#         webvisor:true
#    });
# </script>
# <noscript><div><img src="https://mc.yandex.ru/watch/79575823" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <!--Rating@Mail.ru LOGO-->
# <br>&nbsp;<a target="_top" href="http://top.mail.ru/jump?from=360064"><img src="http://de.c7.b5.a0.top.mail.ru/counter?js=na;id=360064;t=52" alt="Рейтинг@Mail.ru" title="Рейтинг@Mail.ru" border="0" height="31" width="88"></a>
# <!--/LOGO-->
# <!--begin of Top100 logo-->
# &nbsp;<a href="http://top100.rambler.ru/top100/"><img src="http://top100-images.rambler.ru/top100/banner-88x31-rambler-gray2.gif" alt="Rambler's Top100" title="Rambler's Top100" border="0" height="31" width="88"></a>
# <!--end of Top100 logo -->
#
# <!--LiveInternet counter-->
# <script type="text/javascript">
# <!--
# document.write("&nbsp;<a href='http://www.liveinternet.ru/click' "+
# "target=_blank><img src='http://counter.yadro.ru/hit?t11.2;r"+
# escape(document.referrer)+((typeof(screen)=="undefined")?"":
# ";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
# screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
# ";"+Math.random()+
# "' alt='' title='LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня' "+
# "border=0 width=88 height=31><\/a>")
# //-->
# </script>
# <!--/LiveInternet-->
# <!-- Google -->
# <script src="http://www.google-analytics.com/urchin.js" type="text/javascript">
# </script>
# <script type="text/javascript">
# _uacct = "UA-650354-2";
# urchinTracker();
# </script>
# </noindex></center>
# </body></html>

# %% [markdown]
# ## 2. `parse.py`
#
# После того, как мы скачали файл с исходным кодом веб-страницы, нам нужно выделить из него информацию. Исходный код страницы выглядит примерно так:
#
#     <html><head><title>Мурманск : архив погоды</title>
#       <link rel="stylesheet" href="css/styles1.css" type="text/css">
#       <link rel="stylesheet" href="css/clicktravel.css" type="text/css"><link rel="stylesheet" href="css/weather.css" type="text/css"> <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/207129/360.js"></script>
#       <script async type='text/javascript' src='//s.luxupcdnc.com/t/common_402.js'></script>
#     </head>
#     <body bgcolor="white" topmargin="0" marginheight="0">
#
#       <center><div id="counters" style="position:absolute; display:none; width:1px; height:1px; z-index:-1"><IMG SRC="http://ww.hmn.ru/counterdb.php?data=NS4yMjguODkuNzI/ISM1LjIyOC44OS43Mj8hI01vemlsbGEvNS4wIChNYWNpbnRvc2g7IEludGVsIE1hYyBPUyBYIDEwLjE1OyBydjo5Ny4wKSBHZWNrby8yMDEwMDEwMSBGaXJlZm94Lzk3LjA/ISM4PyEjaHR0cDovL3d3dy5obW4ucnUvaW5kZXgucGhwP2luZGV4PTgmdmFsdWU9MjIxMTM/ISMwPyEjMD8hIzEwPyEjMD8hIzIyMTEz" width=1 height=1 border=0>        <img src="http://counter.rambler.ru/top100.cnt?319821" alt="Rambler's Top100" width="1" height="1" border="0"></div><table width="790" border="0" cellspacing="0" cellpadding="0" height="38" class="px_blue_fon" style="margin:0px 0px 10px 0px;">
#       <tr>
#         <td height="27" >
#         <table border="0" cellspacing="0" cellpadding="3" class="m12" height="20" width="100%">
#           <tr>
#             <td align="right" nowrap width="3%"><img src="img/ico_top_travel.gif" width="25" height="25" title="Каталог стран, городов, описание достопримечательностей, климат стран и городов мира, карты стран, поиск попутчиков, туристическая система поиска"></td>
#             <td width="5%" nowrap><a href="http://www.svali.ru" class="imp" target="_blank"><b>Туризм</b><br>
#             <span class="m11">Свали.ру</span></a></td>
#             <td align="right" width="3%" nowrap><img src="img/1px.gif" width="5" height="1"><img src="img/ico_top_avia.gif" width="25" height="25" title="Погода в аэропортах России и мира"></td>
#             <td width="19%" nowrap><a href="http://avia.meteonovosti.ru/" class="imp"><b>Погода в аэропортах</b><br>
#               <span class="m11">риски задержки</span></a></td>
#     ...
#
# Его вы можете посмотреть в браузере, щелкнув правой кнопкой мыши на странице и выбрав пункт контекстного меню Исходный код (или исходный код выделенного фрагмента). В Хроме также можно нажать Исследовать элемент.
#
# ### Структура веб-страницы
#
# Вся веб-страница состоит из тегов - это слова, обернутые в треугольные скобки, например, `<title>` или `<div align="center">` (во втором случае мы имеем тег с параметром). Эти теги описывают браузеру, как именно нужно отображать веб-страницу. Теги могут быть одинарными и двойными - внутрь блоков, которые описывают вторые, можно поместить какой-то еще контент. Закрывающий тег должен иметь тот же тип, что и открывающий, но начинаться с `/`. Пример тега с контентом и параметрами:
#
#     <td align="right" width="3%">Каталог стран, городов, описание достопримечательностей, климат стран и городов мира, карты стран, поиск попутчиков, туристическая система поиска</td>
#
# В приведенном фрагменте описана ячейка таблицы, у которой параметрами заданы ширина и расположение, внутри которой написан текст "Каталог стран...". В подобных тегах и описываеся произвольная веб-страница, и вам нужно найти, в каком именно теге описан фрагмент данных, который нужно сохранить.
#
# Вообще, вся веб-страница делится на два блока: `<head> ... </head>` и `<body> ... </body>`. В первом описываются метаданные страницы, (например, что должно быть написано в названии вкладки и какие файлы со стилями подключать), а во втором располагается уже всё то, что мы видим на самой странице. Поэтому теги, содержащие нужные вам данные, нужно искать внутри блока body.
#
# ### Вернемся к заданию
#
# Нужно описать класс Parser, который можно будет использовать следующим образом:

# %%
import bs4
import re
import requests
import json
FILE_PATH = "weather.html"
PARSED_FILE_PATH = "weather.json"
class Parser:
    def __init__(self, source=FILE_PATH):
        self.source = source
    def parse(self):
        with open(self.source, "r", encoding='koi8-r') as file:
            web_page = file.read()
        soup = bs4.BeautifulSoup(web_page, 'html.parser')
        table = soup.find_all("table", attrs={"class": "m80"})[0]
        time = []                  # создадим список, где будут храниться все значения времени по порядку в таблице
        wind = []                  # а сюда будем добавлять направление ветра
        tr = table.tr              # первый тег tr - это заголовок таблицы, он нам не нужен, поэтому сразу переходим к
                                   # циклу, где ищем следующий соседний тег <tr>
        while tr.find_next_sibling("tr"):  # если следующего тега нет, значит таблица кончилась, можно выходить из цикла
            tr = tr.find_next_sibling("tr")  # теперь tr - это следующий тег <tr> на странице
            if tr.td.b is not None and tr.td["class"][0] == "m11":  # последняя строка таблицы, оказывается, тоже содержит
                                              # тег <b>, поэтому еще и по классу будем фильтровать
                time.extend(tr.td.b)          # дописываем время в список результатов времени, если мы оказались в той
                                              # строке таблицы, где есть время (а таблица слегка криво построена)
                wind.extend(tr.find_all("td")[7])
        d = {}
        for t in time:
            for w in wind:
                d[t] = d.get(t, w)
        return d
    def save(self, parsed_file_path):
        d = self.parse()
        with open(parsed_file_path, "w") as f:
            json.dump(d, f, ensure_ascii=False, indent=4)
# parser = Parser(source=FILE_PATH)    # в конструкторе он принимает путь к файлу, сохраненному Downloader'ом
# parser.parse()                       # должен вернуться список или словарь данных, полученных из кода страницы
# parser.save(PARSED_FILE_PATH)        # сохраняет данные в виде json- или yaml-файла
# Out:
# {'21:00': 'Ю', '18:00': 'Ю', '15:00': 'Ю', '12:00': 'Ю', '9:00': 'Ю', '6:00': 'Ю', '3:00': 'Ю', '00:00': 'Ю'}
# {'21:00': 'Ю', '18:00': 'Ю', '15:00': 'Ю', '12:00': 'Ю', '9:00': 'Ю', '6:00': 'Ю', '3:00': 'Ю', '00:00': 'Ю'}
# <class 'dict'>

# %% [markdown]
# Внутри метода parse нужно использовать библиотеку Beautiful Soup. Документация по ней приведена [здесь](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# Разберем небольшой пример, что можно сделать с использованием этой библиотеки в данных о погоде. Соберем данные со страницы http://www.hmn.ru/index.php?index=8&value=22113&tz=3&start=2022-11-20&fin=2022-11-28&x=10&y=5.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-11-30%20%D0%B2%2004.03.05.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-11-30%20%D0%B2%2004.03.05.png)

# %% [markdown]
# Нажмем на любое значение из таблицы правой кнопкой мыши и выберем Исследовать элемент. Поскольку значений в таблице много, нам ничего не даст использование какого-то конкретного элемента, поэтому найдем тег, в который обернут этот элемент - и в нашем случае это тег table с атрибутом `class="m80"`. Посмотрим, сколько на странице содержится таблиц с таким же классом:

# %%
import bs4
import re
import requests
# web_page = requests.get(
#     "weather.html", stream=True,    
# ).content  # сохранили код веб-страницы в переменную
with open(FILE_PATH, "r", encoding='koi8-r') as file:
            web_page = file.read()
soup = bs4.BeautifulSoup(web_page, 'html.parser')    # создали объект супа
len(soup.find_all("table", attrs={"class": "m80"}))  # смотрим длину списка таблиц с таким классом
# Out:
# 2

# %% [markdown]
# Надо выбрать, какая из этих двух таблиц та самая. Пойдем с конца:

# %%
# soup.find_all("table", attrs={"class": "m80"})[-1]
import json
PARSED_FILE_PATH = "weather.json"
def some_logic(parsed_file_path=PARSED_FILE_PATH):
    with open(parsed_file_path, "r") as f:
        data = json.load(f)
    return data
# print(some_logic(PARSED_FILE_PATH))
# Out:
# {'21:00': 'Ю', '18:00': 'Ю', '15:00': 'Ю', '12:00': 'Ю', '9:00': 'Ю', '6:00': 'Ю', '3:00': 'Ю', '00:00': 'Ю'}

# %% [markdown]
# Здесь нет наших значений, поэтому будем работать с 0-й таблицей.

# %%
table = soup.find_all("table", attrs={"class": "m80"})[0]
# таблица имеет четкую структуру тегов tr и td, поэтому можем просто индексами выбрать нужную информацию
table.find_all("tr")[:10]
# Out:
# [<tr align="center" class="fon_gray_light">
#  <td class="m11" width="15%">Дата и время (местное)</td>
#  <td class="m11">Характер<br/>
#              погоды</td>
#  <td class="m11">Т<br/>
#              (<sup>o</sup>C)</td>
#  <td class="m11">Тd<br/>
#              (<sup>o</sup>C)</td>
#  <td class="m11">Отн.<br/>
#              влаж.<br/>
#              (%)</td>
#  <td class="m11">Атм.<br/>
#              давл.<br/>
#              (мм)</td>
#  <td class="m11">Ветер<br/>
#              (м/с)</td>
#  <td class="m11">Индекс<br/>
#  <a href="index.php?index=14&amp;value=8">комф.</a>,<br/>
#  <a href="index.php?index=14&amp;value=13">УФИ</a>
#  </td>
#  <td class="m11" width="6%">Кол-во<br/>
#              осад-<br/>
#              ков</td>
#  <td class="m11">Высота<br/>
#              снега (см)</td>
#  </tr>,
#  <tr>
#  <td align="center" class="m11"><b>21:00</b><br/>28.11.2022г.</td>
#  <td align="center" class="m11" valign="middle"><img height="50" src="img/signs/n108.gif" title="пасмурно" width="44"/><br/>пасмурно</td>
#  <td class="td11 temp_37" nowrap=""><span id="bfcd450"></span></td>
#  <td class="td11 temp_36" nowrap=""><span id="bfcd451"></span></td>
#  <td class="td11 rh_37">83</td>
#  <td class="td11 temp_38">768</td>
#  <td class="no_gap" height="83">
#  <table cellspacing="0" height="100%" width="100%"><tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_6" width="35%">6</td></tr>
#  <tr height="50%"><td class="td11 ff_5" colspan="2">порывы<br/>10</td></tr>
#  </table>
#  </td>
#  <td align="center" class="ff_6"><div class="td11">6</div><div class="uvi"><font class="text-uvi" color="grey">0</font></div></td>
#  <td class="td11">0.0<div style="font-size: 9px">
#              мм за<br/>12 ч</div></td>
#  <td class="td11"><span id="bfcd452"></span></td></tr>,
#  <tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_6" width="35%">6</td></tr>,
#  <tr height="50%"><td class="td11 ff_5" colspan="2">порывы<br/>10</td></tr>,
#  <tr class="fon_gray_light">
#  <td align="center" class="m11"><b>18:00</b><br/>28.11.2022г.</td>
#  <td align="center" class="m11" valign="middle"><img height="50" src="img/signs/n108.gif" title="пасмурно" width="44"/><br/>пасмурно</td>
#  <td class="td11 temp_37" nowrap=""><span id="bfcd453"></span></td>
#  <td class="td11 temp_36" nowrap=""><span id="bfcd454"></span></td>
#  <td class="td11 rh_37">82</td>
#  <td class="td11 temp_38">768</td>
#  <td class="no_gap" height="83">
#  <table cellspacing="0" height="100%" width="100%"><tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_5" width="35%">5</td></tr>
#  <tr height="50%"><td class="td11 ff_5" colspan="2">порывы<br/>9</td></tr>
#  </table>
#  </td>
#  <td align="center" class="ff_6"><div class="td11">6</div><div class="uvi"><font class="text-uvi" color="grey">0</font></div></td>
#  <td class="td11">-</td>
#  <td class="td11"><span id="bfcd455"></span></td></tr>,
#  <tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_5" width="35%">5</td></tr>,
#  <tr height="50%"><td class="td11 ff_5" colspan="2">порывы<br/>9</td></tr>,
#  <tr>
#  <td align="center" class="m11"><b>15:00</b><br/>28.11.2022г.</td>
#  <td align="center" class="m11" valign="middle"><img height="50" src="img/signs/n108.gif" title="пасмурно" width="44"/><br/>пасмурно</td>
#  <td class="td11 temp_37" nowrap=""><span id="bfcd456"></span></td>
#  <td class="td11 temp_36" nowrap=""><span id="bfcd457"></span></td>
#  <td class="td11 rh_37">84</td>
#  <td class="td11 temp_38">768</td>
#  <td class="no_gap" height="83">
#  <table cellspacing="0" height="100%" width="100%"><tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_4" width="35%">4</td></tr>
#  <tr height="50%"><td class="td11 ff_4" colspan="2">порывы<br/>7</td></tr>
#  </table>
#  </td>
#  <td align="center" class="ff_6"><div class="td11">6</div><div class="uvi"><font class="text-uvi" color="grey">0</font></div></td>
#  <td class="td11">-</td>
#  <td class="td11"><span id="bfcd458"></span></td></tr>,
#  <tr height="50%">
#  <td class="td11 wind_180" width="65%">Ю</td>
#  <td class="td11 ff_4" width="35%">4</td></tr>,
#  <tr height="50%"><td class="td11 ff_4" colspan="2">порывы<br/>7</td></tr>]

# %%
time = []                  # создадим список, где будут храниться все значения времени по порядку в таблице
wind = []                  # а сюда будем добавлять направление ветра
tr = table.tr              # первый тег tr - это заголовок таблицы, он нам не нужен, поэтому сразу переходим к
                           # циклу, где ищем следующий соседний тег <tr>
while tr.find_next_sibling("tr"):  # если следующего тега нет, значит таблица кончилась, можно выходить из цикла
    tr = tr.find_next_sibling("tr")  # теперь tr - это следующий тег <tr> на странице
    if tr.td.b is not None and tr.td["class"][0] == "m11":  # последняя строка таблицы, оказывается, тоже содержит
                                                            # тег <b>, поэтому еще и по классу будем фильтровать
        time.extend(tr.td.b)          # дописываем время в список результатов времени, если мы оказались в той
                                      # строке таблицы, где есть время (а таблица слегка криво построена)
        wind.extend(tr.find_all("td")[7])  # и в том же случае дописываем направление ветра
print(*zip(time, wind), sep="\n")   # выведем результат на экран, объединив два списка в список кортежей  ('21:00', 'Ю')
# Out:
# ('21:00', 'Ю')
# ('18:00', 'Ю')
# ('15:00', 'Ю')
# ('12:00', 'Ю')
# ('9:00', 'Ю')
# ('6:00', 'Ю')
# ('3:00', 'Ю')
# ('00:00', 'Ю')
# ('21:00', 'Ю')
# ('18:00', 'Ю')
# ('15:00', 'Ю')
# ('12:00', 'Ю')

# %% [markdown]
# ## 3. `data.py`
#
# С собранными и сохраненными данными нужно что-то делать. В этом файле опишите любые классы и функции, которые будут выдавать какие-то осмысленные результаты обработки собранных данных. Обязательно должна быть функция или метод класса, который считывает данные из json или yaml и поставляет их другим функциям/методам в виде питоновских объектов.

# %% [markdown]
# ## 4. `__init__.py`
#
# Здесь опишем точку входа в наше приложение для потребителя. Опишите функцию process, которая будет принимать на вход адрес страницы, которую мы хотим заскрапить, опциональным аргументом путь к файлу, который будет хранить копию страницы на локальном компьютере, и еще одним опциональным аргументом - путь к файлу, куда мы сохраним результаты парсинга страницы. Возвращать эта функция должна результат исполнения какой-то части логики, описанной в data.py. Также в этом файле должны использоваться сущности из остальных наших файлов, соответственно, их нужно импортировать в начале файла.

# %%
from download import Downloader
from parser import Parser
from data import some_logic
URL = "http://www.hmn.ru/index.php?index=8&value=22113&tz=3&start=2022-11-20&fin=2022-11-28&x=10&y=5"
FILE_PATH = "weather.html"
PARSED_FILE_PATH = "weather.json"
def process(url, web_page_path=None, data_path=None):
    Url = url.split('?')
    params = Url[1].split('&')
    d = {}
    for i in params:
        I = i.split('=')
        if I[1].isdigit():
            d[I[0]] = d.get(I[0], 0) + int(I[1])
        else:
            d[I[0]] = d.get(I[0], '') + I[1]
    if web_page_path == None:
        downloader = Downloader(Url[0], d)
        parser = Parser()
    else:
        downloader = Downloader(Url[0], d, web_page_path)
        parser = Parser(web_page_path)
    if data_path == None:
        d = some_logic()
    else:
        some_logic(data_path)
    return d
process(URL)
# Out:
# {'21:00': 'Ю',
#  '18:00': 'Ю',
#  '15:00': 'Ю',
#  '12:00': 'Ю',
#  '9:00': 'Ю',
#  '6:00': 'Ю',
#  '3:00': 'Ю',
#  '00:00': 'Ю'}
